# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
from fuel.streams import ServerDataStream

train_stream = ServerDataStream(('sax_features','targets'), False)

# %%
ei = train_stream.get_epoch_iterator()

# %%
d = next(ei)

print d[1].shape
# Out:
# {u'shape': [10, 1], u'fortran_order': False, u'descr': u'<i4'}
# int32
# {u'shape': [10, 30, 80, 80], u'fortran_order': False, u'descr': u'<f8'}
# float64
# {u'shape': [10, 2], u'fortran_order': False, u'descr': u'<f4'}
# float32
# (10, 30, 80, 80)

# %%
for i in range(len(d[1])):
    plt.figure(figsize=(15, 5))
    for j in range(10):
        plt.subplot(1, 10, j+1)
        plt.imshow(d[1][i][j])
    plt.show()
