# %%
import numpy as np
import dicom

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
f = dicom.read_file('/home/thomas/Kaggle/heart/data-kaggle/train/1/study/2ch_21/IM-4572-0001.dcm')

# %%
img = f.pixel_array.astype(np.int)

# %%
plt.imshow(img)
